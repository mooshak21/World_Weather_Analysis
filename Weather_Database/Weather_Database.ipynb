# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as req
from datetime import datetime
import time
from scipy.stats import linregress
from config import weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Identify the nearest city for each latitude and longitude combination.

coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 771

# %%
#Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
#starting URL for weathing map api call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5d5c02a7e31ba186b4996762f9473e40

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cotonou
# Processing Record 2 of Set 1 | pizarro
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | bonavista
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | erzin
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | kysyl-syr
# Processing Record 14 of Set 1 | polovinnoye
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | aripuana
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | hervey bay
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | pontes e lacerda
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | gryazi
# Processing Record 29 of Set 1 | wuwei
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | tarare
# Processing Record 32 of Set 1 | hay river
# Processing Record 33 of Set 1 | roblin
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | lindas
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | the valley
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | inhambane
# Processing Record 42 of Set 1 | ouro preto do oeste
# Processing Record 43 of Set 1 | atar
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | ipora
# Processing Record 49 of Set 1 | khandyga
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | santa cruz de la palma
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | christchurch
# Processing Record 4 of Set 2 | grand gaube
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | biak
# Processing Record 9 of Set 2 | coos bay
# Processing Record 10 of Set 2 | acu
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | chapais
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | hede
# Processing Record 16 of Set 2 | brownsville
# Processing Record 17 of Set 2 | vestmannaeyjar
# Processing Record 18 of Set 2 | eureka
# Processing Record 19 of Set 2 | akyab
# Processing Record 20 of Set 2 | kavaratti
# Processing Record 21 of Set 2 | sao felix do xingu
# Processing Record 22 of Set 2 | mitsamiouli
# Processing Record 23 of Set 2 | kropotkin
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | port augusta
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | miri
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | kadan
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 2 | hauterive
# Processing Record 38 of Set 2 | lake charles
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | bara
# Processing Record 41 of Set 2 | storsteinnes
# Processing Record 42 of Set 2 | pontianak
# Processing Record 43 of Set 2 | wahiawa
# Processing Record 44 of Set 2 | iacu
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | malyye derbety
# Processing Record 48 of Set 2 | kefalos
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | hamilton
# Processing Record 1 of Set 3 | dunedin
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | isiro
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | kahului
# Processing Record 10 of Set 3 | ossora
# Processing Record 11 of Set 3 | bathsheba
# Processing Record 12 of Set 3 | hun
# Processing Record 13 of Set 3 | paamiut
# Processing Record 14 of Set 3 | terney
# Processing Record 15 of Set 3 | ostrovnoy
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | berlevag
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | coquimbo
# Processing Record 20 of Set 3 | chuguyevka
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | kimbe
# Processing Record 24 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 3 | tura
# Processing Record 26 of Set 3 | lanat
# Processing Record 27 of Set 3 | belmonte
# Processing Record 28 of Set 3 | klaksvik
# Processing Record 29 of Set 3 | san patricio
# Processing Record 30 of Set 3 | cuiluan
# Processing Record 31 of Set 3 | lahaina
# Processing Record 32 of Set 3 | praia
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | tarakan
# Processing Record 35 of Set 3 | port blair
# Processing Record 36 of Set 3 | uglovskoye
# Processing Record 37 of Set 3 | goderich
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | honiara
# Processing Record 40 of Set 3 | kilindoni
# Processing Record 41 of Set 3 | panguna
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 3 | supaul
# Processing Record 45 of Set 3 | tighina
# Processing Record 46 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | emba
# Processing Record 49 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 3 | acari
# Processing Record 1 of Set 4 | bilibino
# Processing Record 2 of Set 4 | verkhnyaya inta
# Processing Record 3 of Set 4 | prince rupert
# Processing Record 4 of Set 4 | great yarmouth
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | srednekolymsk
# Processing Record 7 of Set 4 | richards bay
# Processing Record 8 of Set 4 | esil
# Processing Record 9 of Set 4 | sioux lookout
# Processing Record 10 of Set 4 | zelenogradsk
# Processing Record 11 of Set 4 | kencong
# Processing Record 12 of Set 4 | cape town
# Processing Record 13 of Set 4 | qujing
# Processing Record 14 of Set 4 | shuyskoye
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | buala
# Processing Record 17 of Set 4 | asau
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | west bay
# Processing Record 20 of Set 4 | nyurba
# Processing Record 21 of Set 4 | sakakah
# Processing Record 22 of Set 4 | san cristobal
# Processing Record 23 of Set 4 | anito
# Processing Record 24 of Set 4 | teluknaga
# Processing Record 25 of Set 4 | cap malheureux
# Processing Record 26 of Set 4 | acapulco
# Processing Record 27 of Set 4 | high prairie
# Processing Record 28 of Set 4 | ocampo
# Processing Record 29 of Set 4 | te anau
# Processing Record 30 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | east london
# Processing Record 34 of Set 4 | redcliffe
# Processing Record 35 of Set 4 | lorengau
# Processing Record 36 of Set 4 | esmeraldas
# Processing Record 37 of Set 4 | vostok
# Processing Record 38 of Set 4 | westport
# Processing Record 39 of Set 4 | saint-joseph
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | maxixe
# Processing Record 42 of Set 4 | tahta
# Processing Record 43 of Set 4 | geelong
# Processing Record 44 of Set 4 | lichuan
# Processing Record 45 of Set 4 | san quintin
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | san miguel chicaj
# Processing Record 49 of Set 4 | kawalu
# Processing Record 50 of Set 4 | padang
# Processing Record 1 of Set 5 | togur
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | kalabo
# Processing Record 5 of Set 5 | kondinskoye
# Processing Record 6 of Set 5 | santa isabel
# Processing Record 7 of Set 5 | vagur
# Processing Record 8 of Set 5 | zhigansk
# Processing Record 9 of Set 5 | verkh-chebula
# Processing Record 10 of Set 5 | batagay
# Processing Record 11 of Set 5 | nanpiao
# Processing Record 12 of Set 5 | cherskiy
# Processing Record 13 of Set 5 | puerto escondido
# Processing Record 14 of Set 5 | kihei
# Processing Record 15 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | tual
# Processing Record 18 of Set 5 | chuy
# Processing Record 19 of Set 5 | sao joaquim
# Processing Record 20 of Set 5 | xuddur
# Processing Record 21 of Set 5 | vanimo
# Processing Record 22 of Set 5 | duku
# Processing Record 23 of Set 5 | punto fijo
# Processing Record 24 of Set 5 | olean
# Processing Record 25 of Set 5 | saint-georges
# Processing Record 26 of Set 5 | grimshaw
# Processing Record 27 of Set 5 | tuensang
# Processing Record 28 of Set 5 | chipinge
# Processing Record 29 of Set 5 | longyearbyen
# Processing Record 30 of Set 5 | benguela
# Processing Record 31 of Set 5 | grindavik
# Processing Record 32 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 5 | alexandria
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | palm coast
# Processing Record 37 of Set 5 | yumen
# Processing Record 38 of Set 5 | rongcheng
# Processing Record 39 of Set 5 | buckeye
# Processing Record 40 of Set 5 | camargo
# Processing Record 41 of Set 5 | argelia
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | orel
# Processing Record 45 of Set 5 | petatlan
# Processing Record 46 of Set 5 | warmbad
# Processing Record 47 of Set 5 | kununurra
# Processing Record 48 of Set 5 | ouargaye
# Processing Record 49 of Set 5 | hinton
# Processing Record 50 of Set 5 | general roca
# Processing Record 1 of Set 6 | neryungri
# Processing Record 2 of Set 6 | xinyu
# Processing Record 3 of Set 6 | alyangula
# Processing Record 4 of Set 6 | saskylakh
# Processing Record 5 of Set 6 | lincoln
# Processing Record 6 of Set 6 | tuatapere
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | agaro
# Processing Record 9 of Set 6 | lavrentiya
# Processing Record 10 of Set 6 | maragogi
# Processing Record 11 of Set 6 | najran
# Processing Record 12 of Set 6 | kloulklubed
# Processing Record 13 of Set 6 | sindor
# Processing Record 14 of Set 6 | korba
# Processing Record 15 of Set 6 | tarnogskiy gorodok
# Processing Record 16 of Set 6 | ambulu
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | yerbogachen
# Processing Record 19 of Set 6 | rudnichnyy
# Processing Record 20 of Set 6 | san giovanni in fiore
# Processing Record 21 of Set 6 | sobolevo
# Processing Record 22 of Set 6 | lake city
# Processing Record 23 of Set 6 | sambava
# Processing Record 24 of Set 6 | luang prabang
# Processing Record 25 of Set 6 | watertown
# Processing Record 26 of Set 6 | yeppoon
# Processing Record 27 of Set 6 | noblesville
# Processing Record 28 of Set 6 | sidney
# Processing Record 29 of Set 6 | pustoshka
# Processing Record 30 of Set 6 | tacoronte
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | baiao
# Processing Record 33 of Set 6 | nioro
# Processing Record 34 of Set 6 | gumdag
# Processing Record 35 of Set 6 | corinto
# Processing Record 36 of Set 6 | pangody
# Processing Record 37 of Set 6 | khambhaliya
# Processing Record 38 of Set 6 | powell
# Processing Record 39 of Set 6 | manali
# Processing Record 40 of Set 6 | mount gambier
# Processing Record 41 of Set 6 | adrar
# Processing Record 42 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 6 | ambon
# Processing Record 44 of Set 6 | urumqi
# Processing Record 45 of Set 6 | unity
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | portland
# Processing Record 48 of Set 6 | codrington
# Processing Record 49 of Set 6 | redlands
# Processing Record 50 of Set 6 | neka
# Processing Record 1 of Set 7 | arona
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | changying
# Processing Record 4 of Set 7 | mananara
# Processing Record 5 of Set 7 | touros
# Processing Record 6 of Set 7 | nyrob
# Processing Record 7 of Set 7 | maniitsoq
# Processing Record 8 of Set 7 | necochea
# Processing Record 9 of Set 7 | raudeberg
# Processing Record 10 of Set 7 | shetpe
# Processing Record 11 of Set 7 | aloleng
# Processing Record 12 of Set 7 | rankovce
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | vila franca do campo
# Processing Record 15 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 7 | shingu
# Processing Record 17 of Set 7 | gorgan
# Processing Record 18 of Set 7 | cabcab
# Processing Record 19 of Set 7 | lazaro cardenas
# Processing Record 20 of Set 7 | korhogo
# Processing Record 21 of Set 7 | tasiilaq
# Processing Record 22 of Set 7 | impfondo
# Processing Record 23 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 7 | natal
# Processing Record 25 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | nivala
# Processing Record 28 of Set 7 | champerico
# Processing Record 29 of Set 7 | clarence town
# Processing Record 30 of Set 7 | port hardy
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | bengkulu
# Processing Record 33 of Set 7 | santo antonio do sudoeste
# Processing Record 34 of Set 7 | hami
# Processing Record 35 of Set 7 | arman
# Processing Record 36 of Set 7 | zabolotovka
# Processing Record 37 of Set 7 | nishihara
# Processing Record 38 of Set 7 | dawson creek
# Processing Record 39 of Set 7 | soyo
# Processing Record 40 of Set 7 | yatou
# Processing Record 41 of Set 7 | pokrovskoye
# Processing Record 42 of Set 7 | osoyoos
# Processing Record 43 of Set 7 | dauphin
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | alcudia
# Processing Record 46 of Set 7 | kaeo
# Processing Record 47 of Set 7 | abay
# Processing Record 48 of Set 7 | zhumadian
# Processing Record 49 of Set 7 | hovd
# Processing Record 50 of Set 7 | tumaco
# Processing Record 1 of Set 8 | kasongo-lunda
# Processing Record 2 of Set 8 | nipawin
# Processing Record 3 of Set 8 | sorgun
# Processing Record 4 of Set 8 | ilulissat
# Processing Record 5 of Set 8 | puri
# Processing Record 6 of Set 8 | praia da vitoria
# Processing Record 7 of Set 8 | port-gentil
# Processing Record 8 of Set 8 | zapolyarnyy
# Processing Record 9 of Set 8 | estevan
# Processing Record 10 of Set 8 | noumea
# Processing Record 11 of Set 8 | manambrag
# City not found. Skipping...
# Processing Record 12 of Set 8 | mersing
# Processing Record 13 of Set 8 | puksoozero
# Processing Record 14 of Set 8 | arawa
# Processing Record 15 of Set 8 | aswan
# Processing Record 16 of Set 8 | xam nua
# Processing Record 17 of Set 8 | farah
# Processing Record 18 of Set 8 | angra
# City not found. Skipping...
# Processing Record 19 of Set 8 | ketchikan
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | sooke
# Processing Record 22 of Set 8 | rio grande
# Processing Record 23 of Set 8 | french harbor
# Processing Record 24 of Set 8 | agadir
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | tlacotepec
# Processing Record 27 of Set 8 | anda
# Processing Record 28 of Set 8 | ismailia
# Processing Record 29 of Set 8 | husavik
# Processing Record 30 of Set 8 | muscat
# Processing Record 31 of Set 8 | micheweni
# Processing Record 32 of Set 8 | hurricane
# Processing Record 33 of Set 8 | innisfail
# Processing Record 34 of Set 8 | manokwari
# Processing Record 35 of Set 8 | pandan
# Processing Record 36 of Set 8 | pastavy
# Processing Record 37 of Set 8 | talnakh
# Processing Record 38 of Set 8 | poum
# Processing Record 39 of Set 8 | tommot
# Processing Record 40 of Set 8 | bowen
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | clarksburg
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 45 of Set 8 | cayenne
# Processing Record 46 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 8 | bac lieu
# Processing Record 48 of Set 8 | dekar
# Processing Record 49 of Set 8 | northam
# Processing Record 50 of Set 8 | esperance
# Processing Record 1 of Set 9 | marsabit
# Processing Record 2 of Set 9 | luderitz
# Processing Record 3 of Set 9 | tilichiki
# Processing Record 4 of Set 9 | kalmunai
# Processing Record 5 of Set 9 | isangel
# Processing Record 6 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 7 of Set 9 | rio gallegos
# Processing Record 8 of Set 9 | svetlyy
# Processing Record 9 of Set 9 | lata
# Processing Record 10 of Set 9 | iskilip
# Processing Record 11 of Set 9 | dagda
# Processing Record 12 of Set 9 | port lincoln
# Processing Record 13 of Set 9 | atambua
# Processing Record 14 of Set 9 | krasnoarmeysk
# Processing Record 15 of Set 9 | trinidad
# Processing Record 16 of Set 9 | arteaga
# Processing Record 17 of Set 9 | zastron
# Processing Record 18 of Set 9 | mumford
# Processing Record 19 of Set 9 | opuwo
# Processing Record 20 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 9 | ewa beach
# Processing Record 22 of Set 9 | kushima
# Processing Record 23 of Set 9 | asfi
# Processing Record 24 of Set 9 | yaan
# Processing Record 25 of Set 9 | camacha
# Processing Record 26 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 27 of Set 9 | faya
# Processing Record 28 of Set 9 | tornio
# Processing Record 29 of Set 9 | okhotsk
# Processing Record 30 of Set 9 | mezen
# Processing Record 31 of Set 9 | port hedland
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | takoradi
# Processing Record 34 of Set 9 | whitehorse
# Processing Record 35 of Set 9 | nalut
# Processing Record 36 of Set 9 | nha trang
# Processing Record 37 of Set 9 | saint anthony
# Processing Record 38 of Set 9 | roebourne
# Processing Record 39 of Set 9 | nsanje
# Processing Record 40 of Set 9 | mizdah
# Processing Record 41 of Set 9 | resistencia
# Processing Record 42 of Set 9 | sorong
# Processing Record 43 of Set 9 | le vauclin
# Processing Record 44 of Set 9 | qostanay
# Processing Record 45 of Set 9 | antalaha
# Processing Record 46 of Set 9 | bambous virieux
# Processing Record 47 of Set 9 | provideniya
# Processing Record 48 of Set 9 | funadhoo
# Processing Record 49 of Set 9 | tomatlan
# Processing Record 50 of Set 9 | luorong
# Processing Record 1 of Set 10 | andijon
# Processing Record 2 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 10 | college
# Processing Record 4 of Set 10 | higuey
# City not found. Skipping...
# Processing Record 5 of Set 10 | kiruna
# Processing Record 6 of Set 10 | ushtobe
# Processing Record 7 of Set 10 | ahuimanu
# Processing Record 8 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 10 | edd
# Processing Record 10 of Set 10 | baoning
# Processing Record 11 of Set 10 | fare
# Processing Record 12 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 10 | baijiantan
# Processing Record 14 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 10 | poya
# Processing Record 17 of Set 10 | labuhan
# Processing Record 18 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 10 | sept-iles
# Processing Record 20 of Set 10 | kenai
# Processing Record 21 of Set 10 | talcahuano
# Processing Record 22 of Set 10 | puerto colombia
# Processing Record 23 of Set 10 | mandera
# Processing Record 24 of Set 10 | murgab
# Processing Record 25 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 10 | uvinza
# Processing Record 27 of Set 10 | sucre
# Processing Record 28 of Set 10 | enid
# Processing Record 29 of Set 10 | sangar
# Processing Record 30 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 10 | kilinochchi
# Processing Record 32 of Set 10 | saint-jean-de-maurienne
# Processing Record 33 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 10 | lodja
# Processing Record 35 of Set 10 | miandrivazo
# Processing Record 36 of Set 10 | joshimath
# Processing Record 37 of Set 10 | oytal
# Processing Record 38 of Set 10 | hofn
# Processing Record 39 of Set 10 | salalah
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | kidal
# Processing Record 42 of Set 10 | egvekinot
# Processing Record 43 of Set 10 | ikom
# Processing Record 44 of Set 10 | esqueda
# Processing Record 45 of Set 10 | axim
# Processing Record 46 of Set 10 | gravdal
# Processing Record 47 of Set 10 | brae
# Processing Record 48 of Set 10 | hirson
# Processing Record 49 of Set 10 | launceston
# Processing Record 50 of Set 10 | koslan
# Processing Record 1 of Set 11 | renqiu
# Processing Record 2 of Set 11 | birao
# Processing Record 3 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 11 | lompoc
# Processing Record 5 of Set 11 | russell
# Processing Record 6 of Set 11 | bambanglipuro
# Processing Record 7 of Set 11 | gazli
# Processing Record 8 of Set 11 | upata
# Processing Record 9 of Set 11 | dawlatabad
# Processing Record 10 of Set 11 | lusambo
# Processing Record 11 of Set 11 | khani
# Processing Record 12 of Set 11 | hakkari
# Processing Record 13 of Set 11 | nelson bay
# Processing Record 14 of Set 11 | rolla
# Processing Record 15 of Set 11 | belyy yar
# Processing Record 16 of Set 11 | dire
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | tigil
# Processing Record 19 of Set 11 | seymchan
# Processing Record 20 of Set 11 | geraldton
# Processing Record 21 of Set 11 | comodoro rivadavia
# Processing Record 22 of Set 11 | rundu
# Processing Record 23 of Set 11 | devonport
# Processing Record 24 of Set 11 | saint cloud
# Processing Record 25 of Set 11 | shimoda
# Processing Record 26 of Set 11 | umm kaddadah
# Processing Record 27 of Set 11 | karratha
# Processing Record 28 of Set 11 | salinas
# Processing Record 29 of Set 11 | itarema
# Processing Record 30 of Set 11 | puerto del rosario
# Processing Record 31 of Set 11 | ahlat
# Processing Record 32 of Set 11 | nyanguge
# Processing Record 33 of Set 11 | alihe
# Processing Record 34 of Set 11 | ixtapa
# Processing Record 35 of Set 11 | ures
# Processing Record 36 of Set 11 | padampur
# Processing Record 37 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 38 of Set 11 | taseyevo
# Processing Record 39 of Set 11 | pathein
# Processing Record 40 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 11 | zhangye
# Processing Record 42 of Set 11 | santa rosa
# Processing Record 43 of Set 11 | kailua
# Processing Record 44 of Set 11 | khorixas
# Processing Record 45 of Set 11 | verdun
# Processing Record 46 of Set 11 | xining
# Processing Record 47 of Set 11 | lazarev
# Processing Record 48 of Set 11 | ayagoz
# Processing Record 49 of Set 11 | ambilobe
# Processing Record 50 of Set 11 | biu
# Processing Record 1 of Set 12 | timizart
# Processing Record 2 of Set 12 | nuuk
# Processing Record 3 of Set 12 | victor harbor
# Processing Record 4 of Set 12 | terrace bay
# Processing Record 5 of Set 12 | el angel
# Processing Record 6 of Set 12 | anadyr
# Processing Record 7 of Set 12 | umbauba
# Processing Record 8 of Set 12 | taltal
# Processing Record 9 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 12 | mount isa
# Processing Record 11 of Set 12 | sao miguel do araguaia
# Processing Record 12 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 12 | genhe
# Processing Record 14 of Set 12 | pacific grove
# Processing Record 15 of Set 12 | broome
# Processing Record 16 of Set 12 | mokhsogollokh
# Processing Record 17 of Set 12 | hit
# Processing Record 18 of Set 12 | arlit
# Processing Record 19 of Set 12 | mahibadhoo
# Processing Record 20 of Set 12 | buchanan
# Processing Record 21 of Set 12 | beira
# Processing Record 22 of Set 12 | roura
# Processing Record 23 of Set 12 | pamanukan
# Processing Record 24 of Set 12 | kremenki
# Processing Record 25 of Set 12 | camacupa
# Processing Record 26 of Set 12 | perth
# Processing Record 27 of Set 12 | bendorf
# Processing Record 28 of Set 12 | walvis bay
# Processing Record 29 of Set 12 | lethem
# Processing Record 30 of Set 12 | les cayes
# Processing Record 31 of Set 12 | severnyy
# Processing Record 32 of Set 12 | oktyabrskiy
# Processing Record 33 of Set 12 | turukhansk
# Processing Record 34 of Set 12 | havoysund
# Processing Record 35 of Set 12 | gayeri
# Processing Record 36 of Set 12 | celestun
# Processing Record 37 of Set 12 | oistins
# Processing Record 38 of Set 12 | kapit
# Processing Record 39 of Set 12 | lasa
# Processing Record 40 of Set 12 | andenes
# Processing Record 41 of Set 12 | mumbwa
# Processing Record 42 of Set 12 | tukrah
# Processing Record 43 of Set 12 | korampallam
# Processing Record 44 of Set 12 | guiratinga
# Processing Record 45 of Set 12 | sisimiut
# Processing Record 46 of Set 12 | bennington
# Processing Record 47 of Set 12 | omboue
# Processing Record 48 of Set 12 | show low
# Processing Record 49 of Set 12 | borisoglebskiy
# Processing Record 50 of Set 12 | kota kinabalu
# Processing Record 1 of Set 13 | iberia
# Processing Record 2 of Set 13 | kampene
# Processing Record 3 of Set 13 | abnub
# Processing Record 4 of Set 13 | firminopolis
# Processing Record 5 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 6 of Set 13 | samarai
# Processing Record 7 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 13 | vao
# Processing Record 9 of Set 13 | preobrazheniye
# Processing Record 10 of Set 13 | mogapi
# Processing Record 11 of Set 13 | kano
# Processing Record 12 of Set 13 | pandan niog
# Processing Record 13 of Set 13 | palmer
# Processing Record 14 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 15 of Set 13 | garowe
# Processing Record 16 of Set 13 | jacareacanga
# Processing Record 17 of Set 13 | hastings
# Processing Record 18 of Set 13 | nome
# Processing Record 19 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 13 | pilar
# Processing Record 21 of Set 13 | batticaloa
# Processing Record 22 of Set 13 | kodinsk
# Processing Record 23 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 13 | novo aripuana
# Processing Record 25 of Set 13 | bintulu
# Processing Record 26 of Set 13 | nova granada
# Processing Record 27 of Set 13 | namibe
# Processing Record 28 of Set 13 | hobyo
# Processing Record 29 of Set 13 | terme
# Processing Record 30 of Set 13 | alugan
# Processing Record 31 of Set 13 | kingsport
# Processing Record 32 of Set 13 | lakes entrance
# Processing Record 33 of Set 13 | bubaque
# Processing Record 34 of Set 13 | patos de minas
# Processing Record 35 of Set 13 | beringovskiy
# Processing Record 36 of Set 13 | barretos
# Processing Record 37 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 13 | berdigestyakh
# Processing Record 39 of Set 13 | ramnicu sarat
# Processing Record 40 of Set 13 | cockburn town
# Processing Record 41 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 13 | carutapera
# Processing Record 43 of Set 13 | leh
# Processing Record 44 of Set 13 | shelburne
# Processing Record 45 of Set 13 | sirjan
# Processing Record 46 of Set 13 | soe
# Processing Record 47 of Set 13 | khanpur
# Processing Record 48 of Set 13 | quelimane
# Processing Record 49 of Set 13 | blairmore
# Processing Record 50 of Set 13 | kalachinsk
# Processing Record 1 of Set 14 | almeirim
# Processing Record 2 of Set 14 | muroto
# Processing Record 3 of Set 14 | lyubotyn
# Processing Record 4 of Set 14 | tignere
# Processing Record 5 of Set 14 | harper
# Processing Record 6 of Set 14 | japura
# Processing Record 7 of Set 14 | kuytun
# Processing Record 8 of Set 14 | bad wildungen
# Processing Record 9 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 10 of Set 14 | belaya gora
# Processing Record 11 of Set 14 | malkerns
# Processing Record 12 of Set 14 | sabang
# Processing Record 13 of Set 14 | ryotsu
# Processing Record 14 of Set 14 | hagere hiywet
# Processing Record 15 of Set 14 | mayumba
# Processing Record 16 of Set 14 | yenagoa
# Processing Record 17 of Set 14 | poso
# Processing Record 18 of Set 14 | havre-saint-pierre
# Processing Record 19 of Set 14 | energetik
# Processing Record 20 of Set 14 | alta floresta
# Processing Record 21 of Set 14 | kaspiysk
# Processing Record 22 of Set 14 | mahanoro
# Processing Record 23 of Set 14 | morondava
# Processing Record 24 of Set 14 | plettenberg bay
# Processing Record 25 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 26 of Set 14 | nemuro
# Processing Record 27 of Set 14 | arkhangelsk
# Processing Record 28 of Set 14 | diapaga
# Processing Record 29 of Set 14 | fort nelson
# Processing Record 30 of Set 14 | sipkovica
# Processing Record 31 of Set 14 | zhezkazgan
# Processing Record 32 of Set 14 | karpathos
# Processing Record 33 of Set 14 | sirvintos
# Processing Record 34 of Set 14 | platteville
# Processing Record 35 of Set 14 | tabou
# Processing Record 36 of Set 14 | grenfell
# Processing Record 37 of Set 14 | gao
# Processing Record 38 of Set 14 | la uribe
# City not found. Skipping...
# Processing Record 39 of Set 14 | ulladulla
# Processing Record 40 of Set 14 | labytnangi
# Processing Record 41 of Set 14 | chelmsford
# Processing Record 42 of Set 14 | judaberg
# Processing Record 43 of Set 14 | cruz grande
# Processing Record 44 of Set 14 | mahina
# Processing Record 45 of Set 14 | sydney
# Processing Record 46 of Set 14 | balugaon
# Processing Record 47 of Set 14 | labuan
# Processing Record 48 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 14 | chongwe
# Processing Record 50 of Set 14 | road town
# Processing Record 1 of Set 15 | maarianhamina
# Processing Record 2 of Set 15 | puro
# Processing Record 3 of Set 15 | feijo
# Processing Record 4 of Set 15 | barcelos
# Processing Record 5 of Set 15 | coruripe
# Processing Record 6 of Set 15 | nsoko
# Processing Record 7 of Set 15 | port shepstone
# Processing Record 8 of Set 15 | sungaipenuh
# Processing Record 9 of Set 15 | camocim
# Processing Record 10 of Set 15 | robertsport
# Processing Record 11 of Set 15 | miyako
# Processing Record 12 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 15 | iranshahr
# Processing Record 14 of Set 15 | azul
# Processing Record 15 of Set 15 | haines junction
# Processing Record 16 of Set 15 | malang
# Processing Record 17 of Set 15 | otane
# Processing Record 18 of Set 15 | camalu
# Processing Record 19 of Set 15 | muros
# Processing Record 20 of Set 15 | tongren
# Processing Record 21 of Set 15 | vila
# Processing Record 22 of Set 15 | nago
# Processing Record 23 of Set 15 | qurayyat
# Processing Record 24 of Set 15 | levelland
# Processing Record 25 of Set 15 | santa cruz
# Processing Record 26 of Set 15 | itaituba
# Processing Record 27 of Set 15 | konya
# Processing Record 28 of Set 15 | leningradskiy
# Processing Record 29 of Set 15 | sawakin
# Processing Record 30 of Set 15 | pavlysh
# Processing Record 31 of Set 15 | jamame
# Processing Record 32 of Set 15 | onguday
# Processing Record 33 of Set 15 | araure
# Processing Record 34 of Set 15 | mareeba
# Processing Record 35 of Set 15 | camana
# Processing Record 36 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 15 | maumere
# Processing Record 38 of Set 15 | bari
# Processing Record 39 of Set 15 | marienburg
# Processing Record 40 of Set 15 | viedma
# Processing Record 41 of Set 15 | huancavelica
# Processing Record 42 of Set 15 | puerto quijarro
# Processing Record 43 of Set 15 | puerto maldonado
# Processing Record 44 of Set 15 | vestmanna
# Processing Record 45 of Set 15 | zaysan
# Processing Record 46 of Set 15 | avera
# Processing Record 47 of Set 15 | oranjemund
# Processing Record 48 of Set 15 | arandis
# Processing Record 49 of Set 15 | katherine
# Processing Record 50 of Set 15 | loreto
# Processing Record 1 of Set 16 | karasuk
# Processing Record 2 of Set 16 | beloha
# Processing Record 3 of Set 16 | los llanos de aridane
# Processing Record 4 of Set 16 | taoudenni
# Processing Record 5 of Set 16 | numata
# Processing Record 6 of Set 16 | peterhead
# Processing Record 7 of Set 16 | talcher
# Processing Record 8 of Set 16 | aktas
# Processing Record 9 of Set 16 | embonas
# Processing Record 10 of Set 16 | emilio carranza
# Processing Record 11 of Set 16 | high level
# Processing Record 12 of Set 16 | pangnirtung
# Processing Record 13 of Set 16 | tyler
# Processing Record 14 of Set 16 | newport
# Processing Record 15 of Set 16 | rudnogorsk
# Processing Record 16 of Set 16 | selikhino
# Processing Record 17 of Set 16 | mgandu
# Processing Record 18 of Set 16 | tautira
# Processing Record 19 of Set 16 | san juan del cesar
# Processing Record 20 of Set 16 | waddan
# Processing Record 21 of Set 16 | witrivier
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Cotonou      BJ   6.3654    2.4183     80.58        83          40
# 1          Pizarro      CO   4.9533  -77.3660     79.27        83          74
# 2           Atuona      PF  -9.8000 -139.0333     78.31        77          33
# 3   Ribeira Grande      PT  38.5167  -28.7000     69.93        68          36
# 4          Rikitea      PF -23.1203 -134.9692     73.96        76           4
# 5        Bonavista      CA  48.6499  -53.1147     57.11        97         100
# 6   Port Elizabeth      ZA -33.9180   25.5701     57.49        82           0
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     73.26        88          75
# 8          Ushuaia      AR -54.8000  -68.3000     42.46        81          40
# 9            Erzin      TR  36.9559   36.2000     75.92        81           1
#
#    Wind Speed Current Description
# 0       11.50    scattered clouds
# 1        7.16       broken clouds
# 2       21.56    scattered clouds
# 3       10.47    scattered clouds
# 4       11.83           clear sky
# 5       18.92          light rain
# 6       10.36           clear sky
# 7        4.61       broken clouds
# 8        3.44          light rain
# 9        1.50           clear sky

# %%
len(city_data)
# Out:
# 715

# %%
# Create the output file (CSV) and export

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Cotonou      BJ   6.3654    2.4183     80.58        83          40
# 1          Pizarro      CO   4.9533  -77.3660     79.27        83          74
# 2           Atuona      PF  -9.8000 -139.0333     78.31        77          33
# 3   Ribeira Grande      PT  38.5167  -28.7000     69.93        68          36
# 4          Rikitea      PF -23.1203 -134.9692     73.96        76           4
# 5        Bonavista      CA  48.6499  -53.1147     57.11        97         100
# 6   Port Elizabeth      ZA -33.9180   25.5701     57.49        82           0
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     73.26        88          75
# 8          Ushuaia      AR -54.8000  -68.3000     42.46        81          40
# 9            Erzin      TR  36.9559   36.2000     75.92        81           1
#
#    Wind Speed Current Description
# 0       11.50    scattered clouds
# 1        7.16       broken clouds
# 2       21.56    scattered clouds
# 3       10.47    scattered clouds
# 4       11.83           clear sky
# 5       18.92          light rain
# 6       10.36           clear sky
# 7        4.61       broken clouds
# 8        3.44          light rain
# 9        1.50           clear sky
