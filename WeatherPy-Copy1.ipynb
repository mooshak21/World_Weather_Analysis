# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
cities
# Out:
# ['sao joao da barra',
#  'bredasdorp',
#  'beringovskiy',
#  'maiduguri',
#  'jamestown',
#  'bengkulu',
#  'puerto ayora',
#  'bayan',
#  'strezhevoy',
#  'saint-philippe',
#  'nuuk',
#  'luau',
#  'touros',
#  'kruisfontein',
#  'rikitea',
#  'manyana',
#  'kidero',
#  'hamilton',
#  'sawtell',
#  'manakara',
#  'griffith',
#  'mar del plata',
#  'tumannyy',
#  'narsaq',
#  'avarua',
#  'saint-gilles',
#  'busselton',
#  'chuy',
#  'mahebourg',
#  'albany',
#  'barrow',
#  'vila franca do campo',
#  'pisco',
#  'cidreira',
#  'poronaysk',
#  'loubomo',
#  'bethel',
#  'atuona',
#  'starodub',
#  'victoria',
#  'kupang',
#  'weligama',
#  'bluff',
#  'hilo',
#  'lasa',
#  'ericeira',
#  'malwan',
#  'utiroa',
#  'margate',
#  'east london',
#  'dikson',
#  'sao miguel do araguaia',
#  'ushuaia',
#  'kokkola',
#  'yellowknife',
#  'ribeira grande',
#  'punta arenas',
#  'cape town',
#  'hobart',
#  'sharjah',
#  'laguna',
#  'ippy',
#  'illoqqortoormiut',
#  'kodiak',
#  'faanui',
#  'tasiilaq',
#  'taolanaro',
#  'kapaa',
#  'chokurdakh',
#  'vaini',
#  'yulara',
#  'serafimovich',
#  'itaobim',
#  'asau',
#  'hermanus',
#  'padang',
#  'viedma',
#  'novoagansk',
#  'nichlaul',
#  'paliyad',
#  'kassala',
#  'esperance',
#  'coahuayana',
#  'provideniya',
#  'bintulu',
#  'georgetown',
#  'saldanha',
#  'lompoc',
#  'hofn',
#  'cabo rojo',
#  'flinders',
#  'ostrovnoy',
#  'maltahohe',
#  'lobva',
#  'orumiyeh',
#  'hithadhoo',
#  'tadine',
#  'norman wells',
#  'saskylakh',
#  'severo-kurilsk',
#  'senador guiomard',
#  'nikolskoye',
#  'agadez',
#  'baran',
#  'itoman',
#  'katsuura',
#  'lamu',
#  'tuktoyaktuk',
#  'cabo san lucas',
#  'kailua',
#  'new norfolk',
#  'samoylovka',
#  'panguipulli',
#  'longyearbyen',
#  'pierre',
#  'soyo',
#  'bathsheba',
#  'plettenberg bay',
#  'thompson',
#  'lavrentiya',
#  'mareeba',
#  'mataura',
#  'axim',
#  'tsihombe',
#  'maldonado',
#  'west fargo',
#  'chagda',
#  'butaritari',
#  'bridlington',
#  'ambilobe',
#  'barentsburg',
#  'alofi',
#  'qaanaaq',
#  'saint-francois',
#  'necochea',
#  'khilok',
#  'deputatskiy',
#  'khash',
#  'broome',
#  'penzance',
#  'san patricio',
#  'sitka',
#  'luderitz',
#  'san cristobal',
#  'yar-sale',
#  'port alfred',
#  'lumut',
#  'sao filipe',
#  'bonavista',
#  'rapid valley',
#  'meulaboh',
#  'wollongong',
#  'sao raimundo das mangabeiras',
#  'nguiu',
#  'hami',
#  'mezica',
#  'conde',
#  'mitsamiouli',
#  'la paz',
#  'kismayo',
#  'ust-kachka',
#  'santa rosa',
#  'te anau',
#  'nampula',
#  'vodnyy',
#  'umm kaddadah',
#  'hasaki',
#  'iqaluit',
#  'kulevcha',
#  'arraial do cabo',
#  'aksu',
#  'ayan',
#  'kahului',
#  'spassk-dalniy',
#  'fort nelson',
#  'eltham',
#  'khatanga',
#  'cristobal obregon',
#  'warwick',
#  'anadyr',
#  'amderma',
#  'le port',
#  'tiksi',
#  'port hardy',
#  'sorland',
#  'upernavik',
#  'kargopol',
#  'vao',
#  'airai',
#  'leningradskiy',
#  'yerofey pavlovich',
#  'lebu',
#  'tura',
#  'doka',
#  'katihar',
#  'cahors',
#  'linchuan',
#  'castro',
#  'san jose',
#  'cibitoke',
#  'saint-augustin',
#  'ancud',
#  'torbay',
#  'dandong',
#  'miri',
#  'kamenskoye',
#  'celina',
#  'maneadero',
#  'doctor pedro p. pena',
#  'blind river',
#  'canarana',
#  'porto walter',
#  'umm durman',
#  'constitucion',
#  'nome',
#  'aklavik',
#  'beno-yurt',
#  'half moon bay',
#  'nemuro',
#  'ouadda',
#  'nuevo progreso',
#  'krasnoselkup',
#  'mount gambier',
#  'novaya bryan',
#  'tamandare',
#  'kosonsoy',
#  'tanout',
#  'naze',
#  'san blas',
#  'miyang',
#  'shchigry',
#  'apucarana',
#  'lakes entrance',
#  'iquique',
#  'sao paulo de olivenca',
#  'nerchinsk',
#  'bosaso',
#  'abong mbang',
#  'high level',
#  'grand river south east',
#  'zolotkovo',
#  'sinkat',
#  'carnarvon',
#  'nanortalik',
#  'llanes',
#  'toliary',
#  'baykit',
#  'black diamond',
#  'sulina',
#  'chapais',
#  'san jeronimo',
#  'dingle',
#  'vanimo',
#  'palabuhanratu',
#  'whitley bay',
#  'timizart',
#  'carballo',
#  'challapata',
#  'gull lake',
#  'yankton',
#  'louisbourg',
#  'dongsheng',
#  'inuvik',
#  'coihaique',
#  'plouzane',
#  'montepuez',
#  'moron',
#  'vauvert',
#  'kolda',
#  'port blair',
#  'souillac',
#  'la palma',
#  'limbang',
#  'bilibino',
#  'tynda',
#  'bambous virieux',
#  'kazalinsk',
#  'zaraza',
#  'los alamos',
#  'sosenskiy',
#  'slave lake',
#  'college',
#  'rio grande',
#  'fuente palmera',
#  'vallenar',
#  'moree',
#  'sharan',
#  'wattegama',
#  'salaga',
#  'lagoa',
#  'leh',
#  'ponta do sol',
#  'westport',
#  'kaitangata',
#  'tokur',
#  'porto novo',
#  'acapulco',
#  'mys shmidta',
#  'lamar',
#  'kalmunai',
#  'san juan',
#  'thinadhoo',
#  'zhigansk',
#  'pangnirtung',
#  'damietta',
#  'baghdad',
#  'pevek',
#  'oriximina',
#  'srednekolymsk',
#  'balimo',
#  'isangel',
#  'anjozorobe',
#  'sinnamary',
#  'irbeyskoye',
#  'cayenne',
#  'codrington',
#  'los llanos de aridane',
#  'namibe',
#  'port elizabeth',
#  'nadym',
#  'geraldton',
#  'samalaeulu',
#  'falealupo',
#  'vitim',
#  'atbasar',
#  'kudahuvadhoo',
#  'samusu',
#  'henties bay',
#  'vila velha',
#  'rolim de moura',
#  'nanpiao',
#  'cockburn town',
#  'nizhneyansk',
#  'pychas',
#  'humboldt',
#  'imbituba',
#  'labuhan',
#  'ardistan',
#  'alamogordo',
#  'san vicente',
#  'artyk',
#  'bjerkvik',
#  'rawannawi',
#  'fortuna',
#  'veraval',
#  'huarmey',
#  'deoli',
#  'egvekinot',
#  'olinda',
#  'balikpapan',
#  'puerto madero',
#  'huanuco',
#  'willowmore',
#  'galdar',
#  'sao borja',
#  'erzin',
#  'kitaibaraki',
#  'harper',
#  'darhan',
#  'teya',
#  'nambucca heads',
#  'tezu',
#  'nivala',
#  'riyadh',
#  'pangai',
#  'bourail',
#  'hualmay',
#  'mayo',
#  'saint-pierre',
#  'belushya guba',
#  'kavaratti',
#  'ryotsu',
#  'adrar',
#  'nybro',
#  'kampong chhnang',
#  'abu kamal',
#  'yerbogachen',
#  'kiunga',
#  'matagami',
#  'adre',
#  'lodja',
#  'calverton',
#  'morden',
#  'ceuasul-de campie',
#  'macaboboni',
#  'ucluelet',
#  'mersing',
#  'wahiawa',
#  'cam ranh',
#  'melo',
#  'florina',
#  'rantepao',
#  'shingu',
#  'cherskiy',
#  'goundam',
#  'ngukurr',
#  'haradok',
#  'lokosovo',
#  'east hemet',
#  'sisimiut',
#  'gizo',
#  'hambantota',
#  'attawapiskat',
#  'vestmannaeyjar',
#  'serebryansk',
#  'katobu',
#  'oum hadjer',
#  'talnakh',
#  'havre-saint-pierre',
#  'cozumel',
#  'krutinka',
#  'kisanga',
#  'salalah',
#  'sakakah',
#  'cabedelo',
#  'piacabucu',
#  'samarai',
#  'comodoro rivadavia',
#  'nhulunbuy',
#  'ballina',
#  'portland',
#  'marcona',
#  'maragogi',
#  'zwedru',
#  'klaksvik',
#  'ilhabela',
#  'batagay-alyta',
#  'kjollefjord',
#  'papara',
#  'yangjiang',
#  'bennettsville',
#  'paamiut',
#  'manjakandriana',
#  'kabanjahe',
#  'ahipara',
#  'andenes',
#  'falkoping',
#  'belaya gora',
#  'mahadday weyne',
#  'pilar',
#  'saleaula',
#  'burica',
#  'petropavlovsk-kamchatskiy',
#  'puerto leguizamo',
#  'grindavik',
#  'elko',
#  'hokitika',
#  'grand gaube',
#  'toppenish',
#  'tabory',
#  'mumford',
#  'anastasiyevskaya',
#  'guasdualito',
#  'cheuskiny',
#  'pochutla',
#  'luanda',
#  'orlik',
#  'wellington',
#  'umzimvubu',
#  'iralaya',
#  'auburn',
#  'vengerovo',
#  'russell',
#  'hwange',
#  'santo domingo',
#  'araguaina',
#  'lisala',
#  'taoudenni',
#  'shimoda',
#  'guerrero negro',
#  'prince rupert',
#  'portpatrick',
#  'burgeo',
#  'kamaishi',
#  'beisfjord',
#  'sur',
#  'storsteinnes',
#  'mackenzie',
#  'tateyama',
#  'sechura',
#  'lihula',
#  'dicabisagan',
#  'reconquista',
#  'jacksonville beach',
#  'saint anthony',
#  'laje',
#  'barcelos',
#  'hovd',
#  'avera',
#  'mirabad',
#  'husavik',
#  'kilembe',
#  'opuwo',
#  'anchorage',
#  'sao jose da coroa grande',
#  'walvis bay',
#  'port-cartier',
#  'escanaba',
#  'jackson',
#  'saint-joseph',
#  'baculin',
#  'bolshoy log',
#  'kayes',
#  'keti bandar',
#  'kendari',
#  'rocha',
#  'falavarjan',
#  'olafsvik',
#  'polyarnyy',
#  'natal',
#  'ordzhonikidze',
#  'coatlan',
#  'mount isa',
#  'ayagoz',
#  'malinovoye ozero',
#  'dolbeau',
#  'lethem',
#  'asfi',
#  'kirn',
#  'caravelas',
#  'khandyga',
#  'rio gallegos',
#  'manokwari',
#  'ekhabi',
#  'garwa',
#  'wanaka',
#  'thongwa',
#  'canatlan',
#  'tuatapere',
#  'cap malheureux',
#  'jiddah',
#  'waipawa',
#  'bolu',
#  'tarko-sale',
#  'tshane',
#  'haines junction',
#  'sale',
#  'rockport',
#  'chalmette',
#  'kouqian',
#  'batken',
#  'chazuta',
#  'kihei',
#  'madaoua',
#  'kuala lipis',
#  'vredendal',
#  'vardo',
#  'indiana',
#  'luorong',
#  'flers',
#  'esfarayen',
#  'tautira',
#  'kamenka',
#  'collierville',
#  'rawlins',
#  'anjar',
#  'abhar',
#  'bognor regis',
#  'ilulissat',
#  'santa cruz',
#  'port augusta',
#  'rexburg',
#  'sabang',
#  'clyde river',
#  'tazovskiy',
#  'evensk',
#  'sept-iles',
#  'atlantic city',
#  'falun',
#  'praia da vitoria',
#  'rungata',
#  'ramshir',
#  'auki',
#  'pallasovka',
#  'mocambique',
#  'pedernales',
#  'saint george',
#  'kyzyl',
#  'richards bay',
#  'tarrega',
#  'casma',
#  'dalvik',
#  'urumqi',
#  'sheltozero',
#  'mogadishu',
#  'goderich',
#  'youkounkoun',
#  'agha jari',
#  'peniche',
#  'tiznit',
#  'maykor',
#  'luganville',
#  'panzhihua',
#  'veliki preslav',
#  'san ignacio',
#  'marathon',
#  'uni',
#  'mahibadhoo',
#  'bubaque',
#  'sao felix do xingu',
#  'cortes',
#  'mtambile',
#  'pacific grove',
#  'agucadoura',
#  'port hedland',
#  'rehoboth',
#  'bom jesus',
#  'tahoua']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | maiduguri
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | bayan
# Processing Record 9 of Set 1 | strezhevoy
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | nuuk
# Processing Record 12 of Set 1 | luau
# Processing Record 13 of Set 1 | touros
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | manyana
# Processing Record 17 of Set 1 | kidero
# Processing Record 18 of Set 1 | hamilton
# Processing Record 19 of Set 1 | sawtell
# Processing Record 20 of Set 1 | manakara
# Processing Record 21 of Set 1 | griffith
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | saint-gilles
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | vila franca do campo
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | poronaysk
# Processing Record 36 of Set 1 | loubomo
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | starodub
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | kupang
# Processing Record 42 of Set 1 | weligama
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | lasa
# Processing Record 46 of Set 1 | ericeira
# Processing Record 47 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 1 | margate
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | sao miguel do araguaia
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | kokkola
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | sharjah
# Processing Record 11 of Set 2 | laguna
# Processing Record 12 of Set 2 | ippy
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | yulara
# Processing Record 22 of Set 2 | serafimovich
# Processing Record 23 of Set 2 | itaobim
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | padang
# Processing Record 27 of Set 2 | viedma
# Processing Record 28 of Set 2 | novoagansk
# Processing Record 29 of Set 2 | nichlaul
# Processing Record 30 of Set 2 | paliyad
# Processing Record 31 of Set 2 | kassala
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | coahuayana
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | bintulu
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | cabo rojo
# Processing Record 41 of Set 2 | flinders
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | maltahohe
# Processing Record 44 of Set 2 | lobva
# Processing Record 45 of Set 2 | orumiyeh
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | tadine
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | severo-kurilsk
# Processing Record 1 of Set 3 | senador guiomard
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | agadez
# Processing Record 4 of Set 3 | baran
# Processing Record 5 of Set 3 | itoman
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | lamu
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | kailua
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | samoylovka
# Processing Record 13 of Set 3 | panguipulli
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | pierre
# Processing Record 16 of Set 3 | soyo
# Processing Record 17 of Set 3 | bathsheba
# Processing Record 18 of Set 3 | plettenberg bay
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | lavrentiya
# Processing Record 21 of Set 3 | mareeba
# Processing Record 22 of Set 3 | mataura
# Processing Record 23 of Set 3 | axim
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | maldonado
# Processing Record 26 of Set 3 | west fargo
# Processing Record 27 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | bridlington
# Processing Record 30 of Set 3 | ambilobe
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | alofi
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | saint-francois
# Processing Record 35 of Set 3 | necochea
# Processing Record 36 of Set 3 | khilok
# Processing Record 37 of Set 3 | deputatskiy
# Processing Record 38 of Set 3 | khash
# Processing Record 39 of Set 3 | broome
# Processing Record 40 of Set 3 | penzance
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | yar-sale
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | lumut
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | bonavista
# Processing Record 50 of Set 3 | rapid valley
# Processing Record 1 of Set 4 | meulaboh
# Processing Record 2 of Set 4 | wollongong
# Processing Record 3 of Set 4 | sao raimundo das mangabeiras
# Processing Record 4 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | mezica
# Processing Record 7 of Set 4 | conde
# Processing Record 8 of Set 4 | mitsamiouli
# Processing Record 9 of Set 4 | la paz
# Processing Record 10 of Set 4 | kismayo
# Processing Record 11 of Set 4 | ust-kachka
# Processing Record 12 of Set 4 | santa rosa
# Processing Record 13 of Set 4 | te anau
# Processing Record 14 of Set 4 | nampula
# Processing Record 15 of Set 4 | vodnyy
# Processing Record 16 of Set 4 | umm kaddadah
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | kulevcha
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | aksu
# Processing Record 22 of Set 4 | ayan
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | spassk-dalniy
# Processing Record 25 of Set 4 | fort nelson
# Processing Record 26 of Set 4 | eltham
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | cristobal obregon
# Processing Record 29 of Set 4 | warwick
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | le port
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | port hardy
# Processing Record 35 of Set 4 | sorland
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | kargopol
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | yerofey pavlovich
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | doka
# Processing Record 45 of Set 4 | katihar
# Processing Record 46 of Set 4 | cahors
# Processing Record 47 of Set 4 | linchuan
# City not found. Skipping...
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | san jose
# Processing Record 50 of Set 4 | cibitoke
# Processing Record 1 of Set 5 | saint-augustin
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | dandong
# Processing Record 5 of Set 5 | miri
# Processing Record 6 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 5 | celina
# Processing Record 8 of Set 5 | maneadero
# Processing Record 9 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 5 | blind river
# Processing Record 11 of Set 5 | canarana
# Processing Record 12 of Set 5 | porto walter
# Processing Record 13 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | beno-yurt
# City not found. Skipping...
# Processing Record 18 of Set 5 | half moon bay
# Processing Record 19 of Set 5 | nemuro
# Processing Record 20 of Set 5 | ouadda
# Processing Record 21 of Set 5 | nuevo progreso
# Processing Record 22 of Set 5 | krasnoselkup
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | novaya bryan
# Processing Record 25 of Set 5 | tamandare
# Processing Record 26 of Set 5 | kosonsoy
# Processing Record 27 of Set 5 | tanout
# Processing Record 28 of Set 5 | naze
# Processing Record 29 of Set 5 | san blas
# Processing Record 30 of Set 5 | miyang
# Processing Record 31 of Set 5 | shchigry
# Processing Record 32 of Set 5 | apucarana
# Processing Record 33 of Set 5 | lakes entrance
# Processing Record 34 of Set 5 | iquique
# Processing Record 35 of Set 5 | sao paulo de olivenca
# Processing Record 36 of Set 5 | nerchinsk
# Processing Record 37 of Set 5 | bosaso
# Processing Record 38 of Set 5 | abong mbang
# Processing Record 39 of Set 5 | high level
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | zolotkovo
# Processing Record 42 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | nanortalik
# Processing Record 45 of Set 5 | llanes
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | baykit
# Processing Record 48 of Set 5 | black diamond
# Processing Record 49 of Set 5 | sulina
# Processing Record 50 of Set 5 | chapais
# Processing Record 1 of Set 6 | san jeronimo
# Processing Record 2 of Set 6 | dingle
# Processing Record 3 of Set 6 | vanimo
# Processing Record 4 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | whitley bay
# Processing Record 6 of Set 6 | timizart
# Processing Record 7 of Set 6 | carballo
# Processing Record 8 of Set 6 | challapata
# Processing Record 9 of Set 6 | gull lake
# Processing Record 10 of Set 6 | yankton
# Processing Record 11 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 6 | dongsheng
# Processing Record 13 of Set 6 | inuvik
# Processing Record 14 of Set 6 | coihaique
# Processing Record 15 of Set 6 | plouzane
# Processing Record 16 of Set 6 | montepuez
# Processing Record 17 of Set 6 | moron
# Processing Record 18 of Set 6 | vauvert
# Processing Record 19 of Set 6 | kolda
# Processing Record 20 of Set 6 | port blair
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | la palma
# Processing Record 23 of Set 6 | limbang
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | tynda
# Processing Record 26 of Set 6 | bambous virieux
# Processing Record 27 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 6 | zaraza
# Processing Record 29 of Set 6 | los alamos
# Processing Record 30 of Set 6 | sosenskiy
# Processing Record 31 of Set 6 | slave lake
# Processing Record 32 of Set 6 | college
# Processing Record 33 of Set 6 | rio grande
# Processing Record 34 of Set 6 | fuente palmera
# Processing Record 35 of Set 6 | vallenar
# Processing Record 36 of Set 6 | moree
# Processing Record 37 of Set 6 | sharan
# Processing Record 38 of Set 6 | wattegama
# Processing Record 39 of Set 6 | salaga
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | leh
# Processing Record 42 of Set 6 | ponta do sol
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | kaitangata
# Processing Record 45 of Set 6 | tokur
# Processing Record 46 of Set 6 | porto novo
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 6 | lamar
# Processing Record 50 of Set 6 | kalmunai
# Processing Record 1 of Set 7 | san juan
# Processing Record 2 of Set 7 | thinadhoo
# Processing Record 3 of Set 7 | zhigansk
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | damietta
# Processing Record 6 of Set 7 | baghdad
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | oriximina
# Processing Record 9 of Set 7 | srednekolymsk
# Processing Record 10 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 11 of Set 7 | isangel
# Processing Record 12 of Set 7 | anjozorobe
# Processing Record 13 of Set 7 | sinnamary
# Processing Record 14 of Set 7 | irbeyskoye
# Processing Record 15 of Set 7 | cayenne
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | port elizabeth
# Processing Record 20 of Set 7 | nadym
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 7 | vitim
# Processing Record 25 of Set 7 | atbasar
# Processing Record 26 of Set 7 | kudahuvadhoo
# Processing Record 27 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 7 | henties bay
# Processing Record 29 of Set 7 | vila velha
# Processing Record 30 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 7 | nanpiao
# Processing Record 32 of Set 7 | cockburn town
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 7 | pychas
# Processing Record 35 of Set 7 | humboldt
# Processing Record 36 of Set 7 | imbituba
# Processing Record 37 of Set 7 | labuhan
# Processing Record 38 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 7 | alamogordo
# Processing Record 40 of Set 7 | san vicente
# Processing Record 41 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 7 | bjerkvik
# Processing Record 43 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | veraval
# Processing Record 46 of Set 7 | huarmey
# Processing Record 47 of Set 7 | deoli
# Processing Record 48 of Set 7 | egvekinot
# Processing Record 49 of Set 7 | olinda
# Processing Record 50 of Set 7 | balikpapan
# Processing Record 1 of Set 8 | puerto madero
# Processing Record 2 of Set 8 | huanuco
# Processing Record 3 of Set 8 | willowmore
# Processing Record 4 of Set 8 | galdar
# Processing Record 5 of Set 8 | sao borja
# Processing Record 6 of Set 8 | erzin
# Processing Record 7 of Set 8 | kitaibaraki
# Processing Record 8 of Set 8 | harper
# Processing Record 9 of Set 8 | darhan
# Processing Record 10 of Set 8 | teya
# Processing Record 11 of Set 8 | nambucca heads
# Processing Record 12 of Set 8 | tezu
# Processing Record 13 of Set 8 | nivala
# Processing Record 14 of Set 8 | riyadh
# Processing Record 15 of Set 8 | pangai
# Processing Record 16 of Set 8 | bourail
# Processing Record 17 of Set 8 | hualmay
# Processing Record 18 of Set 8 | mayo
# Processing Record 19 of Set 8 | saint-pierre
# Processing Record 20 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | ryotsu
# Processing Record 23 of Set 8 | adrar
# Processing Record 24 of Set 8 | nybro
# Processing Record 25 of Set 8 | kampong chhnang
# Processing Record 26 of Set 8 | abu kamal
# Processing Record 27 of Set 8 | yerbogachen
# Processing Record 28 of Set 8 | kiunga
# Processing Record 29 of Set 8 | matagami
# Processing Record 30 of Set 8 | adre
# Processing Record 31 of Set 8 | lodja
# Processing Record 32 of Set 8 | calverton
# Processing Record 33 of Set 8 | morden
# Processing Record 34 of Set 8 | ceuasul-de campie
# City not found. Skipping...
# Processing Record 35 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 8 | ucluelet
# Processing Record 37 of Set 8 | mersing
# Processing Record 38 of Set 8 | wahiawa
# Processing Record 39 of Set 8 | cam ranh
# Processing Record 40 of Set 8 | melo
# Processing Record 41 of Set 8 | florina
# Processing Record 42 of Set 8 | rantepao
# Processing Record 43 of Set 8 | shingu
# Processing Record 44 of Set 8 | cherskiy
# Processing Record 45 of Set 8 | goundam
# Processing Record 46 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 8 | haradok
# Processing Record 48 of Set 8 | lokosovo
# Processing Record 49 of Set 8 | east hemet
# Processing Record 50 of Set 8 | sisimiut
# Processing Record 1 of Set 9 | gizo
# Processing Record 2 of Set 9 | hambantota
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | serebryansk
# Processing Record 6 of Set 9 | katobu
# Processing Record 7 of Set 9 | oum hadjer
# Processing Record 8 of Set 9 | talnakh
# Processing Record 9 of Set 9 | havre-saint-pierre
# Processing Record 10 of Set 9 | cozumel
# Processing Record 11 of Set 9 | krutinka
# Processing Record 12 of Set 9 | kisanga
# Processing Record 13 of Set 9 | salalah
# Processing Record 14 of Set 9 | sakakah
# Processing Record 15 of Set 9 | cabedelo
# Processing Record 16 of Set 9 | piacabucu
# Processing Record 17 of Set 9 | samarai
# Processing Record 18 of Set 9 | comodoro rivadavia
# Processing Record 19 of Set 9 | nhulunbuy
# Processing Record 20 of Set 9 | ballina
# Processing Record 21 of Set 9 | portland
# Processing Record 22 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 9 | maragogi
# Processing Record 24 of Set 9 | zwedru
# Processing Record 25 of Set 9 | klaksvik
# Processing Record 26 of Set 9 | ilhabela
# Processing Record 27 of Set 9 | batagay-alyta
# Processing Record 28 of Set 9 | kjollefjord
# Processing Record 29 of Set 9 | papara
# Processing Record 30 of Set 9 | yangjiang
# Processing Record 31 of Set 9 | bennettsville
# Processing Record 32 of Set 9 | paamiut
# Processing Record 33 of Set 9 | manjakandriana
# Processing Record 34 of Set 9 | kabanjahe
# Processing Record 35 of Set 9 | ahipara
# Processing Record 36 of Set 9 | andenes
# Processing Record 37 of Set 9 | falkoping
# City not found. Skipping...
# Processing Record 38 of Set 9 | belaya gora
# Processing Record 39 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 40 of Set 9 | pilar
# Processing Record 41 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 9 | burica
# City not found. Skipping...
# Processing Record 43 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 9 | puerto leguizamo
# Processing Record 45 of Set 9 | grindavik
# Processing Record 46 of Set 9 | elko
# Processing Record 47 of Set 9 | hokitika
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | toppenish
# Processing Record 50 of Set 9 | tabory
# Processing Record 1 of Set 10 | mumford
# Processing Record 2 of Set 10 | anastasiyevskaya
# Processing Record 3 of Set 10 | guasdualito
# Processing Record 4 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 10 | pochutla
# Processing Record 6 of Set 10 | luanda
# Processing Record 7 of Set 10 | orlik
# Processing Record 8 of Set 10 | wellington
# Processing Record 9 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 10 | iralaya
# Processing Record 11 of Set 10 | auburn
# Processing Record 12 of Set 10 | vengerovo
# Processing Record 13 of Set 10 | russell
# Processing Record 14 of Set 10 | hwange
# Processing Record 15 of Set 10 | santo domingo
# Processing Record 16 of Set 10 | araguaina
# Processing Record 17 of Set 10 | lisala
# Processing Record 18 of Set 10 | taoudenni
# Processing Record 19 of Set 10 | shimoda
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | prince rupert
# Processing Record 22 of Set 10 | portpatrick
# City not found. Skipping...
# Processing Record 23 of Set 10 | burgeo
# Processing Record 24 of Set 10 | kamaishi
# Processing Record 25 of Set 10 | beisfjord
# Processing Record 26 of Set 10 | sur
# Processing Record 27 of Set 10 | storsteinnes
# Processing Record 28 of Set 10 | mackenzie
# Processing Record 29 of Set 10 | tateyama
# Processing Record 30 of Set 10 | sechura
# Processing Record 31 of Set 10 | lihula
# Processing Record 32 of Set 10 | dicabisagan
# Processing Record 33 of Set 10 | reconquista
# Processing Record 34 of Set 10 | jacksonville beach
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | laje
# Processing Record 37 of Set 10 | barcelos
# Processing Record 38 of Set 10 | hovd
# Processing Record 39 of Set 10 | avera
# Processing Record 40 of Set 10 | mirabad
# Processing Record 41 of Set 10 | husavik
# Processing Record 42 of Set 10 | kilembe
# Processing Record 43 of Set 10 | opuwo
# Processing Record 44 of Set 10 | anchorage
# Processing Record 45 of Set 10 | sao jose da coroa grande
# Processing Record 46 of Set 10 | walvis bay
# Processing Record 47 of Set 10 | port-cartier
# Processing Record 48 of Set 10 | escanaba
# Processing Record 49 of Set 10 | jackson
# Processing Record 50 of Set 10 | saint-joseph
# Processing Record 1 of Set 11 | baculin
# Processing Record 2 of Set 11 | bolshoy log
# City not found. Skipping...
# Processing Record 3 of Set 11 | kayes
# Processing Record 4 of Set 11 | keti bandar
# Processing Record 5 of Set 11 | kendari
# Processing Record 6 of Set 11 | rocha
# Processing Record 7 of Set 11 | falavarjan
# Processing Record 8 of Set 11 | olafsvik
# Processing Record 9 of Set 11 | polyarnyy
# Processing Record 10 of Set 11 | natal
# Processing Record 11 of Set 11 | ordzhonikidze
# Processing Record 12 of Set 11 | coatlan
# City not found. Skipping...
# Processing Record 13 of Set 11 | mount isa
# Processing Record 14 of Set 11 | ayagoz
# Processing Record 15 of Set 11 | malinovoye ozero
# Processing Record 16 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 11 | lethem
# Processing Record 18 of Set 11 | asfi
# Processing Record 19 of Set 11 | kirn
# Processing Record 20 of Set 11 | caravelas
# Processing Record 21 of Set 11 | khandyga
# Processing Record 22 of Set 11 | rio gallegos
# Processing Record 23 of Set 11 | manokwari
# Processing Record 24 of Set 11 | ekhabi
# Processing Record 25 of Set 11 | garwa
# Processing Record 26 of Set 11 | wanaka
# Processing Record 27 of Set 11 | thongwa
# Processing Record 28 of Set 11 | canatlan
# Processing Record 29 of Set 11 | tuatapere
# Processing Record 30 of Set 11 | cap malheureux
# Processing Record 31 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 11 | waipawa
# Processing Record 33 of Set 11 | bolu
# Processing Record 34 of Set 11 | tarko-sale
# Processing Record 35 of Set 11 | tshane
# Processing Record 36 of Set 11 | haines junction
# Processing Record 37 of Set 11 | sale
# Processing Record 38 of Set 11 | rockport
# Processing Record 39 of Set 11 | chalmette
# Processing Record 40 of Set 11 | kouqian
# Processing Record 41 of Set 11 | batken
# Processing Record 42 of Set 11 | chazuta
# Processing Record 43 of Set 11 | kihei
# Processing Record 44 of Set 11 | madaoua
# Processing Record 45 of Set 11 | kuala lipis
# Processing Record 46 of Set 11 | vredendal
# Processing Record 47 of Set 11 | vardo
# Processing Record 48 of Set 11 | indiana
# Processing Record 49 of Set 11 | luorong
# Processing Record 50 of Set 11 | flers
# Processing Record 1 of Set 12 | esfarayen
# Processing Record 2 of Set 12 | tautira
# Processing Record 3 of Set 12 | kamenka
# Processing Record 4 of Set 12 | collierville
# Processing Record 5 of Set 12 | rawlins
# Processing Record 6 of Set 12 | anjar
# Processing Record 7 of Set 12 | abhar
# Processing Record 8 of Set 12 | bognor regis
# Processing Record 9 of Set 12 | ilulissat
# Processing Record 10 of Set 12 | santa cruz
# Processing Record 11 of Set 12 | port augusta
# Processing Record 12 of Set 12 | rexburg
# Processing Record 13 of Set 12 | sabang
# Processing Record 14 of Set 12 | clyde river
# Processing Record 15 of Set 12 | tazovskiy
# Processing Record 16 of Set 12 | evensk
# Processing Record 17 of Set 12 | sept-iles
# Processing Record 18 of Set 12 | atlantic city
# Processing Record 19 of Set 12 | falun
# Processing Record 20 of Set 12 | praia da vitoria
# Processing Record 21 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 12 | ramshir
# Processing Record 23 of Set 12 | auki
# Processing Record 24 of Set 12 | pallasovka
# Processing Record 25 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 12 | pedernales
# Processing Record 27 of Set 12 | saint george
# Processing Record 28 of Set 12 | kyzyl
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | tarrega
# Processing Record 31 of Set 12 | casma
# Processing Record 32 of Set 12 | dalvik
# Processing Record 33 of Set 12 | urumqi
# Processing Record 34 of Set 12 | sheltozero
# Processing Record 35 of Set 12 | mogadishu
# Processing Record 36 of Set 12 | goderich
# Processing Record 37 of Set 12 | youkounkoun
# Processing Record 38 of Set 12 | agha jari
# City not found. Skipping...
# Processing Record 39 of Set 12 | peniche
# Processing Record 40 of Set 12 | tiznit
# Processing Record 41 of Set 12 | maykor
# Processing Record 42 of Set 12 | luganville
# Processing Record 43 of Set 12 | panzhihua
# Processing Record 44 of Set 12 | veliki preslav
# Processing Record 45 of Set 12 | san ignacio
# Processing Record 46 of Set 12 | marathon
# Processing Record 47 of Set 12 | uni
# Processing Record 48 of Set 12 | mahibadhoo
# Processing Record 49 of Set 12 | bubaque
# Processing Record 50 of Set 12 | sao felix do xingu
# Processing Record 1 of Set 13 | cortes
# Processing Record 2 of Set 13 | mtambile
# Processing Record 3 of Set 13 | pacific grove
# Processing Record 4 of Set 13 | agucadoura
# Processing Record 5 of Set 13 | port hedland
# Processing Record 6 of Set 13 | rehoboth
# Processing Record 7 of Set 13 | bom jesus
# Processing Record 8 of Set 13 | tahoua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 557

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sao Joao Da Barra -21.6403  -41.0511     82.49        70          12
# 1         Bredasdorp -34.5322   20.0403     60.12        67           3
# 2       Beringovskiy  63.0500  179.3167     40.10        88          99
# 3          Maiduguri  11.8464   13.1603     89.04        44          74
# 4          Jamestown  42.0970  -79.2353     73.02        53           1
# 5           Bengkulu  -3.8004  102.2655     74.84        90          84
# 6       Puerto Ayora  -0.7393  -90.3518     78.76        93          85
# 7              Bayan  46.0833  127.4000     44.06        95          99
# 8         Strezhevoy  60.7333   77.5889     37.38        94         100
# 9     Saint-Philippe -21.3585   55.7679     67.59        67          52
#
#    Wind Speed Country                 Date
# 0       15.97      BR  2021-09-19 17:20:39
# 1       13.80      ZA  2021-09-19 17:20:27
# 2        7.58      RU  2021-09-19 17:20:39
# 3        3.91      NG  2021-09-19 17:19:08
# 4        4.00      US  2021-09-19 17:19:06
# 5        5.59      ID  2021-09-19 17:20:40
# 6        8.99      EC  2021-09-19 17:20:40
# 7        5.88      CN  2021-09-19 17:20:40
# 8        2.98      RU  2021-09-19 17:20:40
# 9        9.71      RE  2021-09-19 17:20:41

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0  Sao Joao Da Barra      BR  2021-09-19 17:20:39 -21.6403  -41.0511
# 1         Bredasdorp      ZA  2021-09-19 17:20:27 -34.5322   20.0403
# 2       Beringovskiy      RU  2021-09-19 17:20:39  63.0500  179.3167
# 3          Maiduguri      NG  2021-09-19 17:19:08  11.8464   13.1603
# 4          Jamestown      US  2021-09-19 17:19:06  42.0970  -79.2353
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     82.49        70          12       15.97
# 1     60.12        67           3       13.80
# 2     40.10        88          99        7.58
# 3     89.04        44          74        3.91
# 4     73.02        53           1        4.00

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '09/19/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
